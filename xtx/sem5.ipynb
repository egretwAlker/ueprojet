# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../')
from bugless import *
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle

def dump(fn, thing):
  with open(fn, "wb") as f:
    pickle.dump(thing, f)
def load(fn):
  with open(fn, "rb") as f:
    return pickle.load(f)

# %%
labels, corpus = load("preprocessed.pickle")
labels = [x > 5 for x in labels]

# %%
print(len(labels), len(corpus))
# Out:
# 121542 121542

# %%
vectors = load("vectors.pickle")
print(vectors.shape)
# Out:
# (121542, 64687)

# %%
finalexam(labels, vectors, get_knn(1, 5))
# Out:
# {'True negatives': 1398,
#  'False positives': 314,
#  'False negatives': 7783,
#  'True positive': 14473,
#  'Accuracy when on falses': 0.8165887850467289,
#  'Accuracy when on trues': 0.6502965492451473,
#  'Accuracy in total': 0.6621745660881175,
#  'Accuracy in average': 0.7334426671459382}

# %%
finalexam(labels, vectors, get_knn(1, 50))
# Out:
# {'True negatives': 1548,
#  'False positives': 164,
#  'False negatives': 6847,
#  'True positive': 15409,
#  'Accuracy when on falses': 0.9042056074766355,
#  'Accuracy when on trues': 0.6923526240115025,
#  'Accuracy in total': 0.7074849799732977,
#  'Accuracy in average': 0.798279115744069}

# %%
finalexam(labels, vectors, get_knn(1, 500))
# Out:
# {'True negatives': 1566,
#  'False positives': 146,
#  'False negatives': 5071,
#  'True positive': 17185,
#  'Accuracy on falses': 0.9147196261682243,
#  'Accuracy on trues': 0.7721513299784328,
#  'Accuracy in total': 0.7823347797062751,
#  'Accuracy in average': 0.8434354780733286}

# %%
def myplot(x):
    y = []
    y0 = []
    y1 = []
    for a in x:
        print(a)
        d = finalexam(labels, vectors, get_knn(a, 500))
        y.append(d['Accuracy in average'])
        y0.append(d['Accuracy on falses'])
        y1.append(d['Accuracy on trues'])
    plt.plot(x, y, label='Accuracy in average')
    plt.plot(x, y0, label='Accuracy on falses')
    plt.plot(x, y1, label='Accuracy on trues')

    plt.xlabel('balance value')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
myplot(list(range(1, 5)))
# Out:
# 1
# 2
# 3
# 4

# %%
def myplot(x):
    y = []
    y0 = []
    y1 = []
    for a in x:
        print(a)
        d = finalexam(labels, vectors, get_knn(a, 5))
        y.append(d['Accuracy in average'])
        y0.append(d['Accuracy on falses'])
        y1.append(d['Accuracy on trues'])
    plt.plot(x, y, label='Accuracy in average')
    plt.plot(x, y0, label='Accuracy on falses')
    plt.plot(x, y1, label='Accuracy on trues')

    plt.xlabel('balance value')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
myplot(list(range(1, 5)))
# Out:
# 1
# 2
# 3
# 4

# %%
def myplot(x):
    y = []
    y0 = []
    y1 = []
    for a in x:
        print(a)
        d = finalexam(labels, vectors, get_knn(a, 50))
        y.append(d['Accuracy in average'])
        y0.append(d['Accuracy on falses'])
        y1.append(d['Accuracy on trues'])
    plt.plot(x, y, label='Accuracy in average')
    plt.plot(x, y0, label='Accuracy on falses')
    plt.plot(x, y1, label='Accuracy on trues')

    plt.xlabel('balance value')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
myplot(list(range(1, 5)))
# Out:
# 1
# 2
# 3
# 4

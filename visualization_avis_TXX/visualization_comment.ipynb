# %% [markdown]
# # Work with notes and comments

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
import tools as tools
import numpy as np
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# %%
plt.rcParams['lines.markersize'] = 1

# %%
pairs = tools.note_comment_pairs("avis.json")[:5000]

# %% [markdown]
# ## Representation: Bag of words + eulidien distance

# %%
cv = CountVectorizer()
bow = cv.fit_transform([t[1] for t in pairs])

# %%
tsne = TSNE(n_components=2)
tsne_fit = tsne.fit_transform(bow)
# Out:
# /Users/maxhsia/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/maxhsia/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
def myscatter(points2d):
  c = [t[0] for t in pairs[:len(points2d)]]
  scatter = plt.scatter(points2d[:, 0], points2d[:, 1], c=c, cmap='viridis')
  plt.colorbar(scatter)
  plt.show()

myscatter(tsne_fit)

# %% [markdown]
# ### RM
#
# As expected, 1-gram + euclidien distance does not work well. It seems to be able to sometimes be sure of a positive comment though.

# %% [markdown]
# ## Representation: n-grams + eulidien distance/cos distance

# %%
cv = CountVectorizer(ngram_range=[1,3])
bow = cv.fit_transform([t[1] for t in pairs])
tsne = TSNE(n_components=2)
tsne_fit = tsne.fit_transform(bow)

# %%
myscatter(tsne_fit)

# %%
tsne = TSNE(n_components=2, metric=cosine_similarity)
tsne_fit = tsne.fit_transform(bow[:200])
# Out:
# /Users/maxhsia/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:819: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
myscatter(tsne_fit)

# %% [markdown]
# ### RM
#
# Cos distance is slow and quite useless to my surprise. N-grams are a little bit better but nothing too interesting.
# Maybe we need to do a normalization.

# %% [markdown]
# ## Representation: n-grams + TF-IDF + eulidien distance

# %%
tfidf = TfidfVectorizer(ngram_range=[1, 2], norm='l2')
bow = tfidf.fit_transform([t[1] for t in pairs])
tsne = TSNE(n_components=2)
tsne_fit = tsne.fit_transform(bow)

# %%
myscatter(tsne_fit)

# %%
for i in range(len(tsne_fit)):
  if (abs(tsne_fit[i][0]-5)<10 and abs(tsne_fit[i][1]-100)<10):
    print(pairs[i][0], pairs[i][1])
# Out:
# 9.0 Vin d'jeu: Certes ils pouvaient retourner sur les plages qu’ils connaissaient, mais il y avait cette soif de découvrir… Normal pour une race qui, pendant des années et avant d’avoir eu l’excellente idée de se regrouper, se déplace toujours dans la même direction. Cette fusion, cette amitié, cette combinaison permettait d’aller dans un sens ou dans l’autre désormais, une vraie liberté… enfin presque… Car il restait le principal à établir : Une complicité sans faille, une complicité où on n’a pas besoin de se parler pour se comprendre…. Mais ça, c’était encore une longue marche à franchir. La marche du crabe en quelque sorte.
#
# Simple à comprendre, pas facile à gagner, mais tellement subtil !
#
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/11/la-marche-du-crabe/
# 8.0 Vin d'jeu: Si votre jeu prend la poussière sur votre étagère alors peut-être que c’est le moment de redécouvrir cette perle.
# Si votre jeu sort régulièrement, vous aurez sans doute déjà fait un peu le tour de tous les peuples et pouvoirs. Dans ce cas, allez-y pour cette version thématisée. Elle apporte son lot de nouveautés, assez pour revigorer votre envie d’y jouer.
# Si l'avis complet sur Small World of Warcraft vous intéresse, c'est par là: https://www.vindjeu.eu/2020/10/08/small-world-of-warcraft/
# 7.3 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/14/queenz/
# 10.0 Vin d'jeu: Enorme ! Ce jeu est un pur bonheur. Il offre une immersion tout simplement exceptionnelle, comme j’en ai rarement voire jamais vu dans un jeu de société. Ca commence par la description du Monde dans lequel on évolue, que je vous conseille vivement de lire avant de commencer pour profiter au mieux du jeu (et pour avoir quelques indices intéressants si vous êtes attentif…). Ca continue par la description de votre Maison, détaillée et fournie, qui vous permettra de vous mettre dans la peau de  votre famille. Ca se poursuit enfin par toute la partie narrative bien sûr, qui est le cœur vibrant du jeu.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2021/08/01/le-dilemme-du-roi/
# 6.9 Vin d'jeu: si l'avis complet de Mauwi sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/15/mauwi/
# 7.1 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/22/age-of-civilization/
# 7.4 Vin d'jeu: si l'avis complet de La Princesse aux Echelles sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/06/04/la-princesse-aux-echelles/
# 7.0 Le concept est vraiment original et fun, mais à mon sens il n’a pas encore été exploité à sa juste valeur.
# Si l'avis complet sur Mystery House sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/01/mystery-house/
# 8.0 Vin d'jeu: Á 2 ou 3, l’interaction entre les joueurs n’est pas assez marquée. On ne se gêne pas dans les trajectoires et rarement dans les dépassements. Á 5 et 6, là on est trop gêné par les autres. Le circuit ne comportant que 2 ou 3 voies, il devient quasi impossible de doubler et d’établir une stratégie correcte lorsque l’on est dans les derniers. On se contente de subir le jeu des autres. Á 4 joueurs nous avons trouvé l’équilibre parfait. Si vous n’avez pas 4 personnes pour jouer, vous pouvez aussi prendre 2 voitures par joueur. La version solo est aussi très intéressante, elle se joue comme un contre la montre. On utilise alors une feuille de temps pour calculer son score.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2021/02/04/rallyman/
# 7.0 Vin d'jeu: si l'avis complet de Magnum Opus sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/04/10/magnum-opus/
# 6.8 Vin d'jeu: si l'avis complet de Brave Rats sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/06/06/brave-rats/
# 8.0 Quelle belle réussite que cette petite boite !
#
# Assez vite expliqué, rapidement mis en place, pas un seul texte sur les cartes (bon, du coup, ya pas mal de pictos, et parfois imprimés un peu petit selon moi), un graphisme personnel qui rapidement est digéré et apprécié, de la combo agréable, de la rejouabilité, très peu d'interactions (ça peut en freiner, mais nous, ça nous allait très bien : des cartes jouant sur les majo, la possibilité de prendre une carte qui donnerait des PV aux autres, c'est déjà bien).
#
# Les mécaniques ne sont pas réellement nouvelles mais tordues un peu différemment, donnant au titre une réelle identité.
#
# Wild Space n'est pas un deckbuilding du tout, mais vous sentirez une odeur proche. Wild Space n'est pas Card Driven, mais pour autant il fleure un parfum similaire. Wild Space n'a rien à voir avec 7 Wonders, mais on retrouve l'idée de "chainage", mise ici au diapason.
#
# Un carton plein pour ma part. Je ne saurai que trop conseiller ce jeu.
#
# 8,5
# 7.7 Vin d'jeu: si l'avis complet de Wild Space sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/02/05/wild-space/
# 7.7 Vin d'jeu: si l'avis complet sur le Défi de la Reine par Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/04/27/le-defi-de-la-reine/
# 7.2 Vin d'jeu: si l'avis complet de Boss Quest sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/05/25/boss-quest/
# 7.5 Boss Quest peut être décrit un peu à la va-vite comme un Blackjack vidéoludique, où il faut s’approcher autant que possible de la valeur en points de santé de différents boss sans la dépasser. Des cartes Arme d’une valeur de 1 à 7 remplacent les dés, et pour s’assurer que l’on agira rapidement, le jeu récompense par l’attribution d’une modification de règles les joueurs au fur et à mesure qu’ils estiment avoir complété leur main. S’il reste très aléatoire, il l’habille ainsi très bien thématiquement et enrichit astucieusement le stop-ou-encore d’une part tactique… particulièrement agressive.
#
# C’est que Boss Quest est avant tout un jeu où vous aimerez vous taquiner les uns les autres. En laissant une place au hasard et au bluff grâce à la carte que chacun garde secrètement devant lui, il ne vous autorise jamais aucune certitude de victoire, et vous invite continuellement à saper les chances de vos rivaux, à bouleverser les règles de façon à leur retirer toute chance de rester dans la compétition. On tente bien entendu de deviner ce qu’ils peuvent cacher… pour rire énormément au moment de la confrontation avec le boss, que l’on soit tombé juste ou non, le plus important étant évidemment de s’amuser de l’ambiance particulièrement électrique suscitée par le titre.
#
# Ce primat du plaisir est renforcé par les quatre modules de Boss Quest, qui ajoutent considérablement à sa variété et à son interactivité jubilatoire, avec une générosité inattendue de la part d’un jeu d’ambiance à 20 euros !
#
# L'intégralité de l'analyse de Boss Quest est lisible sur VonGuru : https://vonguru.fr/2020/04/13/boss-quest-afin-de-sauver-le-prince-aucune-pitie-pour-vos-rivaux/
# 10.0 Vous pensiez avoir gagné et bien c'est raté!
# Voilà en résumé Boss Quest, tout est jouable jusqu'à la dernière seconde, les derniers peuvent être les premiers dans ce jeu machiavélique.
# 8.9 Vin d'jeu: si l'avis complet sur Unlock Epic Adventures par Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/06/unlock-epic-adventures/
# 7.5 Vin d'jeu: si l'avis complet d'Hades Trap sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/03/04/hades-trap/
# 7.0 Vin d'jeu: Franchement, ça tourne! Plusieurs parties en famille au compteur, notamment ma fille de 7 ans qui adore. C’est facile à emmener, facile à sortir, vite expliqué, et on peut facilement enchaîner plusieurs parties. Le pouvoir de certaines cartes permettent en plus de pimenter un peu les parties.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/11/17/menestrels/
# 9.0 Vin d'jeu: Spy Club est plutôt une très bonne surprise, et bien qu’il ne s’agisse pas d’un jeu d’enquête à proprement parlé, mais d’un thème enquête, on se prête au jeu de manière à la fois agréable pour son gameplay, mais aussi pour la tension qu’il apporte. Son mode campagne ajoute ce « plus » qui le rend plus original et promet une bonne rejouabilité.
# SI l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/15/spy-club/
# 9.0 Vin d'jeu: Istanbul est un bon jeu familial+, avec un plateau renouvelable à l’infini, une mécanique de base (marchand + assistants) très originale, qui tourne à merveille et qui apporte de la profondeur et stratégie au jeu.  La chance a sa place et une certaine répétitivité survient en fin de partie.  Les parties se jouent rapidement (40 minutes) ce qui donne envie d’en faire d’autres tant le jeu est agréable et renouvelable.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/24/istanbul-big-box/
# 8.0 Vin d'jeu: Si vous avez l’habitude des Unlocks, que vous avez joué à toutes les boites, vous risquez d’être légèrement déçu avec celui-ci.  Il ne va plus vous surprendre ni vous étonner autant que les précédents opus.  Sa grande force est son thème.  Je vous conseille d’ailleurs d’y jouer avec des fans de la saga Star Wars.  Ils seront aux anges et rêveront encore longtemps de votre jeu
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/22/unlock-star-wars-escape-game/
# 6.0 Vin d'jeu: Le Gant d’infinité est un jeu plutôt agréable, pas trop complexe mais il reste en retrait en regard de la vivacité de son célèbre grand frère
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/11/28/le-gant-de-linfinite/
# 7.0 Vin d'jeu: Tout cela nous donne un petit jeu, ma foi, agréable à jouer, en particulier pour une partie rapide entre deux joueurs.
# Si l'avis complet de Glasgow sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/17/glasgow/
# 8.0 Tout comme dans Evolution, l’objectif dans Oceans est de se nourrir: 1 PV par poisson ingurgité. Toutes les capacités vont tourner autour de cet objectif simple et direct. Peut-être même un peu trop pour les joueurs les plus aguerris qui trouveront les choix un peu trop faciles. Mais le fun provient des manières différentes de vous nourrir. Vous allez pouvoir vous servir dans les récifs, attaquer d’autres espèces mais aussi voler de la nourriture aux autres ou même profiter d’une attaque d’une autre espèce pour aller se nourrir des restes.
# Vin d'jeu: si l'avis complet d'Oceans sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/07/14/oceans/
# 8.0 Vin d'jeu: Alors, c’est vraiment simple dès qu’on a bien compris que « sa ligne » correspond à la colonne de l’adversaire. On est donc constamment entre jouer une carte pour soi, pour augmenter la valeur d’une colonne, et éviter de faire des cadeaux à son adversaire. Il y a aussi un aspect « attentisme », voir ce que l’autre va jouer pour agir en conséquence. Evidemment, les parties diffèrent à chaque fois car la main de départ n’est jamais la même.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/10/28/dragon-masterfr/
# 10.0 On ne peut que saluer l’imagination de son auteur Aurélien Picolet qui à ma connaissance en est à son premier jeu. Aurélien nous propose à chaque fois des situations loufoques et incitant l’imagination et les fous rire. Chapeau bas!
# Si l'avis complet de Top Ten sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/07/22/top-ten/
# 10.0 On ne peut que saluer l’imagination de son auteur Aurélien Picolet qui à ma connaissance en est à son premier jeu. Aurélien nous propose à chaque fois des situations loufoques et incitant l’imagination et les fous rire. Chapeau bas!
# Si l'avis complet de Top Ten sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/07/22/top-ten/
# 9.0 Vin d'jeu: Certes ils pouvaient retourner sur les plages qu’ils connaissaient, mais il y avait cette soif de découvrir… Normal pour une race qui, pendant des années et avant d’avoir eu l’excellente idée de se regrouper, se déplace toujours dans la même direction. Cette fusion, cette amitié, cette combinaison permettait d’aller dans un sens ou dans l’autre désormais, une vraie liberté… enfin presque… Car il restait le principal à établir : Une complicité sans faille, une complicité où on n’a pas besoin de se parler pour se comprendre…. Mais ça, c’était encore une longue marche à franchir. La marche du crabe en quelque sorte.
#
# Simple à comprendre, pas facile à gagner, mais tellement subtil !
#
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/09/11/la-marche-du-crabe/
# 8.0 Vin d'jeu: Si votre jeu prend la poussière sur votre étagère alors peut-être que c’est le moment de redécouvrir cette perle.
# Si votre jeu sort régulièrement, vous aurez sans doute déjà fait un peu le tour de tous les peuples et pouvoirs. Dans ce cas, allez-y pour cette version thématisée. Elle apporte son lot de nouveautés, assez pour revigorer votre envie d’y jouer.
# Si l'avis complet sur Small World of Warcraft vous intéresse, c'est par là: https://www.vindjeu.eu/2020/10/08/small-world-of-warcraft/
# 10.0 Vin d'jeu: Enorme ! Ce jeu est un pur bonheur. Il offre une immersion tout simplement exceptionnelle, comme j’en ai rarement voire jamais vu dans un jeu de société. Ca commence par la description du Monde dans lequel on évolue, que je vous conseille vivement de lire avant de commencer pour profiter au mieux du jeu (et pour avoir quelques indices intéressants si vous êtes attentif…). Ca continue par la description de votre Maison, détaillée et fournie, qui vous permettra de vous mettre dans la peau de  votre famille. Ca se poursuit enfin par toute la partie narrative bien sûr, qui est le cœur vibrant du jeu.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2021/08/01/le-dilemme-du-roi/
# 7.3 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/14/queenz/
# 6.9 Vin d'jeu: si l'avis complet de Twin it jeux de société sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/05/05/twin-it-jeux-de-societe/
# 7.7 Libellud n'en finit pas d'user son fond de commerce avec ses Dixit like ? Apres Mysterium, Shadow of Amsterdam, voici One key. Le background ? Il n'y en a pas. IL faut trouver la bonne clé vers ..le paradis, le quatrième dimension, la cave de l'immeuble... ? Mystère. C'est vrai qu'on s'en fout.
# Des superbes illustrations aux formes particulières, très claires, mélangeant des détails et/ou des personnages sont le matériel que vous devrez éliminer peu à peu pour garder la substantifique moelle parmi 11 propositions. A chaque tour le MJ vous montrera des indices, vous écarterez une puis 2 cartes.... Si c 'est bon vous continuez, jusqu'au moment où il en restera une. La bonne ?
#
# On avait bien aimé Shadow of Amsterdam malgré un côté un peu chargé sur le visuel, One key est plus épuré et fonctionne bien (il y a une apply qui ne sert pas a grand chose). Bien sûr il y a du hasard et le tirage des indices peut vous être plus ou moins favorable, il faudra alors ruser. Comme quoi le genre illustration/communication non verbale n'a pas tout dit. Rapide, efficace et beau.
# 6.9 Vin d'jeu: si l'avis complet de One Key sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/05/11/one-key/
# 5.0 Ce jeu va forcément vous faire penser à d’autres de la gamme Libellud. Par la disposition des joueurs et la mécanique cela ressemble fortement à Mystérium; et par les illustrations à Dixit. La seule chose qui change va être de devoir nuancer le lien avec votre carte clé. Et c’est peut-être la plus grande difficulté.
#
# C’est un bon jeu mais après deux grands classiques que sont devenus Mystérium et Dixit, celui-là est clairement en-dessous.
#
# La mécanique n’est pas novatrice. Jeu sympathique à jouer que l’on sortira à une soirée entre amis pour faire une ou deux parties.
#
# Mon avis plus complet sur: https://error404.fr/one-key/
# 6.0 One key est (encore) un jeu de déduction à partir d'images dans laquelle un maitre de jeu va tenter de faire deviner des choses aux autres joueurs via des images (comme dans Mysterium). Le matériel est plutôt de bonne qualité et agréable (notamment les illustrations), sans toutefois s'imposer là-dessus (on est en dessous de ses deux grands frères à savoir Dixit et Mysterium). Il propose un twist intéressant en imposant un temps de réflexion limitée via une appli (que je n'ai pas trop aimé utilisé tout de même).
#
# Le problème de One key est qu'il est sorti en 2019, et cette année il y a eu au moins deux déclinaisons du jeu de déduction à base d'images, meilleures que lui : Obscurio et Detective Club. Cela fait passer tout de suite One key au stade de ok game dispensable. Il n'est pas mauvais, mais c'est juste qu'il y a mieux sur le même créneau. J'ai peur du coup, qu'il soit vite oublié....
# 7.0 Ce titre est très clivant : on aime ou pas ! Il plaira à coup sûr aux amoureux des mots qui aiment cette gymnastique cérébrale, mais il pourra assez vite lasser ceux qui apprécient les jeux avec plus d’ambiance.  En tout cas, nous le trouvons beaucoup trop compliqué pour des enfants de 8 ans, nous le recommandons à partir de 12 ans minimum.
# Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2021/05/11/charafe/
# 6.9 Vin d'jeu: si l'avis complet de Mauwi sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/15/mauwi/
# 7.1 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2020/01/22/age-of-civilization/
# 7.1 Vin d'jeu: si l'avis complet de Sneaky Cards sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/04/30/sneaky-cards/
# 9.0 Vin d'jeu: si l'avis complet sur Le Jour et La Nuit sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/06/24/minuit-meurtre-en-mer-extension-le-jour-et-la-nuit/
# 8.3 Ni l’un ni l’autre à mon avis – tout simplement parce que je ne voyais pas d’iceberg. Pour filer la métaphore, Nouvelle Vague serait plutôt un deuxième paquebot, et Le Jour et la Nuit (hors ces nouvelles règles) l’embellissement du premier. Les histoires en sont toujours aussi immersives et dynamiques (un combo rare dans le jeu d’enquêtes), et plus ludiques encore, les enrichissements et propositions d’amélioration convaincants et séduisants, puisqu’ils fluidifient le jeu quand les joueurs sont nombreux, et ajoutent une part de contrôle et de tactique que la plupart appréciera. L’extension prouve un admirable suivi du jeu par son auteur, qui au lieu de se focaliser sur sa prochaine production (le prometteur Music Business, anciennement Vinyle) a préféré s’arrêter sur la précédente pour écouter les joueurs et son instinct. Et avec un packaging plus geek de surcroît, Minuit, Meurtre en Mer a plus d’arguments que jamais pour trouver sa place dans le haut du panier des jeux narratifs.
#
# L'intégralité de la critique est lisible sur VonGuru : https://vonguru.fr/2019/03/01/le-jour-et-la-nuit-extension-en-profondeur-du-jeu-denquetes-competitif-minuit-meurtre-en-mer/
# 6.7 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/04/06/el-maestro/
# 9.4 On se prend au jeu dès que la partie débute, parce que c’est rigolo, parce que dessiner même quand on est nul ça marche toujours bien pour mettre l’ambiance et se moquer gentiment de ses partenaires de jeu.
#
# On aime dessiner, et on aime être maestro. Alors on part assez facilement pour une partition sans musique avec notre maestro dessinateur. Puis même si on dessine mal, en tant que maestro personne ne voit réellement notre dessin, finalement un chef d’orchestre sait-il bien joué de la musique ?
#
# Mon avis complet sur: https://error404.fr/el-maestro/
# 7.8 Vin d'jeu: si l'avis complet sur dans les airs sous la terre par Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/07/25/the-7th-continent-dans-les-airs-sous-la-terre/
# 7.6 Si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/04/28/dice-forge-rebellion/
# 7.6 Vin d'jeu: si l'avis complet sur Vin d'jeu vous intéresse, c'est par là: https://www.vindjeu.eu/2019/02/16/sherlock-la-tombe-de-larcheologue-dernier-appel-mort-un-4-juillet/

# %% [markdown]
# ### RM
#
# So the only good chunk that we've got is because vin d'jeu gives only good grades!
